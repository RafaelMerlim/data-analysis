# %% [markdown]
# ## Desafio 1 do [Paulo Silveira](https://twitter.com/paulo_caelum)
#
# O Paulo fez uma análise rápida e disse que tem 18 filmes sem avaliações, será que ele acertou?
#
# Determine quantos filmes não tem avaliações e quais são esses filmes.

# %%
filmes_com_media.head()
filmes_com_media.sort_values('nota', ascending = True)
filmes_sem_avaliacao = filmes_com_media.query('nota != nota')
filmes_sem_avaliacao
# Out:
#       filmeId  ... nota
# 816      1076  ...  NaN
# 2211     2939  ...  NaN
# 2499     3338  ...  NaN
# 2587     3456  ...  NaN
# 3118     4194  ...  NaN
# 4037     5721  ...  NaN
# 4506     6668  ...  NaN
# 4598     6849  ...  NaN
# 4704     7020  ...  NaN
# 5020     7792  ...  NaN
# 5293     8765  ...  NaN
# 5421    25855  ...  NaN
# 5452    26085  ...  NaN
# 5749    30892  ...  NaN
# 5824    32160  ...  NaN
# 5837    32371  ...  NaN
# 5957    34482  ...  NaN
# 7565    85565  ...  NaN
#
# [18 rows x 4 columns]

# %%
filmes_sem_avaliacao.count()
# Out:
# filmeId    18
# titulo     18
# generos    18
# nota        0
# dtype: int64

# %% [markdown]
# ## Desafio 2 do [Guilherme Silveira](https://twitter.com/guilhermecaelum)
#
# Mudar o nome da coluna nota do dataframe **filmes_com_media** para nota_média após o join.

# %%
filmes_com_media.columns = ['filmeId', 'titulo', 'generos', 'nota_media']
filmes_com_media
# Out:
#       filmeId  ... nota_media
# 0           1  ...   3.920930
# 1           2  ...   3.431818
# 2           3  ...   3.259615
# 3           4  ...   2.357143
# 4           5  ...   3.071429
# ...       ...  ...        ...
# 9737   193581  ...   4.000000
# 9738   193583  ...   3.500000
# 9739   193585  ...   3.500000
# 9740   193587  ...   3.500000
# 9741   193609  ...   4.000000
#
# [9742 rows x 4 columns]

# %% [markdown]
# ## Desafio 3 do [Guilherme Silveira](https://twitter.com/guilhermecaelum)
#
# Colocar o número de avaliações por filme, isto é, não só a média mas o TOTAL de votos por filme.

# %%
avaliacoes.head()
numero_de_avaliacoes = avaliacoes.groupby('filmeId')['usuarioId'].count()
filmes_com_numero_avaliacao = filmes_com_media.join(numero_de_avaliacoes, on="filmeId")
filmes_com_numero_avaliacao.columns = ['filmeId', 'titulo', 'generos', 'nota_media', 'num_ava']
filmes_com_numero_avaliacao
# Out:
#       filmeId                                     titulo  ... nota_media  num_ava
# 0           1                           Toy Story (1995)  ...   3.920930    215.0
# 1           2                             Jumanji (1995)  ...   3.431818    110.0
# 2           3                    Grumpier Old Men (1995)  ...   3.259615     52.0
# 3           4                   Waiting to Exhale (1995)  ...   2.357143      7.0
# 4           5         Father of the Bride Part II (1995)  ...   3.071429     49.0
# ...       ...                                        ...  ...        ...      ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)  ...   4.000000      1.0
# 9738   193583               No Game No Life: Zero (2017)  ...   3.500000      1.0
# 9739   193585                               Flint (2017)  ...   3.500000      1.0
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)  ...   3.500000      1.0
# ...

# %% [markdown]
# ## Desafio 4 do [Thiago Gonçalves](https://twitter.com/tgcsantos)
#
#
# Arredondar as médias (coluna de nota média) para duas casas decimais.

# %%
filmes_com_numero_avaliacao.head()
filmes_com_numero_avaliacao['nota_media'] = round(filmes_com_numero_avaliacao['nota_media'], 2)
filmes_com_numero_avaliacao
# Out:
#       filmeId                                     titulo  ... nota_media  num_ava
# 0           1                           Toy Story (1995)  ...       3.92    215.0
# 1           2                             Jumanji (1995)  ...       3.43    110.0
# 2           3                    Grumpier Old Men (1995)  ...       3.26     52.0
# 3           4                   Waiting to Exhale (1995)  ...       2.36      7.0
# 4           5         Father of the Bride Part II (1995)  ...       3.07     49.0
# ...       ...                                        ...  ...        ...      ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)  ...       4.00      1.0
# 9738   193583               No Game No Life: Zero (2017)  ...       3.50      1.0
# 9739   193585                               Flint (2017)  ...       3.50      1.0
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)  ...       3.50      1.0
# ...

# %% [markdown]
# ## Desafio 5 do [Allan Spadini](https://twitter.com/allanspadini)
#
# Descobrir os generos dos filmes (quais são eles, únicos). (esse aqui o bicho pega)

# %%
lista_generos = []
filmes_com_numero_avaliacao['generos'].str.split('|')
for linha in filmes_com_numero_avaliacao['generos'].str.split('|'):
  for elemento in linha:
    lista_generos.append(elemento)
generos = pd.DataFrame(list(set(lista_generos)))
generos.columns = ['Generos']
generos
# Out:
#                Generos
# 0            Film-Noir
# 1              Romance
# 2             Children
# 3              Western
# 4               Comedy
# 5                Crime
# 6            Animation
# 7             Thriller
# 8              Mystery
# 9               Horror
# 10                 War
# 11           Adventure
# 12             Musical
# 13               Drama
# 14                IMAX
# 15         Documentary
# 16             Fantasy
# 17              Sci-Fi
# 18              Action
# 19  (no genres listed)

# %% [markdown]
# ## Desafio 6 da [Thais André](https://twitter.com/thais_tandre)
#
# Contar o número de aparições de cada genero.

# %%
total_generos = pd.DataFrame(lista_generos)
total_generos.columns = ['Genero']
total_generos['contador'] = 1
aparicoes_filmes = total_generos.groupby('Genero')['contador'].count()
aparicoes_filmes
# Out:
# Genero
# (no genres listed)      34
# Action                1828
# Adventure             1263
# Animation              611
# Children               664
# Comedy                3756
# Crime                 1199
# Documentary            440
# Drama                 4361
# Fantasy                779
# Film-Noir               87
# Horror                 978
# IMAX                   158
# Musical                334
# Mystery                573
# Romance               1596
# Sci-Fi                 980
# Thriller              1894
# War                    382
# Western                167
# Name: contador, dtype: int64

# %% [markdown]
# ## Desafio 7 do [Guilherme Silveira](https://twitter.com/guilhermecaelum)
#
# Plotar o gráfico de aparições de cada genero. Pode ser um gráfico de tipo igual a barra.

# %%
aparicoes_filmes.plot(kind = 'bar')
