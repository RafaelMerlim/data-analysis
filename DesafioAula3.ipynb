# %% [markdown]
# ## Desafio 1 do [Thiago Gonçalves](https://twitter.com/tgcsantos)
#
# Plotar e analisar o Boxplot da média (coluna imbd_score) dos filmes em preto e branco e coloridos.

# %%
import seaborn as sns

imdb['color'].unique()
filmes_preto_branco = imdb.query("color ==  ' Black and White'")
filmes_preto_branco["imdb_score"].plot(kind = 'box', title = 'Preto e Branco')

# %%
filmes_colorido = imdb.query("color ==  'Color'")
filmes_colorido["imdb_score"].plot(kind = 'box', title = 'Colorido')

# %% [markdown]
# ##Desafio 2 do [Guilherme Silveira](https://twitter.com/guilhermecaelum)
#
# No gráfico de **budget por lucro** temos um ponto com muito custo e prejuizo, descubra com é esse filme (budget próximo de 2.5).

# %%
imdb_usa.sort_values('lucro').head(1)['movie_title']
# Out:
# 5    John Carter
# Name: movie_title, dtype: object

# %% [markdown]
# ##Desafio 3 do [Guilherme Silveira](https://twitter.com/guilhermecaelum)
#
#
# Em aula falamos que talvez, filmes mais recentes podem ter prejuizo pois ainda não tiveram tempo de recuperar o investimento. Analise essas informações e nos conte quais foram suas conclusões.

# %%
imdb_usa.head()
sns.scatterplot(x="title_year", y="lucro", data = imdb_usa.query("lucro <= 0 and title_year >= 2013"))

# %% [markdown]
# ## Desafio 4 do [Paulo Silveira](https://twitter.com/paulo_caelum)
#
# Quais foram os filmes da decada pré 2° guerra que tiveram muito lucro.

# %%
sns.scatterplot(x="title_year", y="lucro", data = imdb_usa.query("title_year <= 1939"))

# %%
imdb_usa.query("title_year <= 1939").sort_values('lucro', ascending = False)['movie_title']
# Out:
# 3970                                  Gone with the Wind
# 4449                     Snow White and the Seven Dwarfs
# 4157                                    The Wizard of Oz
# 4958                      Over the Hill to the Poorhouse
# 4812                                 The Broadway Melody
# 4706                                             Top Hat
# 4786                                         42nd Street
# 4427                                        Modern Times
# 2904                               The Prisoner of Zenda
# 3755                                  A Farewell to Arms
# 3960                                       Hell's Angels
# 4272                            Alexander's Ragtime Band
# 4387                          You Can't Take It with You
# 4404                        Mr. Smith Goes to Washington
# 4508                     The Charge of the Light Brigade
# 4810    Intolerance: Love's Struggle Throughout the Ages
# 4824                               It Happened One Night
# 4885                                      The Big Parade
# 4898                                  She Done Him Wrong
# Name: movie_title, dtype: object

# %% [markdown]
# ## Desafio 5 do [Paulo Silveira](https://twitter.com/paulo_caelum)
#
# No gráfico de **filmes_irmaos por dindin** temos alguns pontos estranhos entre 15 e 20. Confirme a tese genial do Paulo que o cidadão estranho é o Woody Allen. (Se ele tiver errado pode cornete nas redes sociais kkkkk)

# %%
sns.scatterplot(x="filmes_irmaos", y="dindin", data = gross_director)

# %%
gross_director.query("filmes_irmaos < 20 and filmes_irmaos > 15")['director_name'].value_counts()
# Out:
# Woody Allen    18
# Tim Burton     16
# Spike Lee      16
# Name: director_name, dtype: int64

# %% [markdown]
# ## Desafio 7 do [Thiago Gonçalves](https://twitter.com/tgcsantos)
#
#
# Calcular a correlação apenas dos filmes pós anos 2000 (Jogar fora filmes antes de 2000) e interpretar essa correlação.

# %%
imdb_usa[["gross", "budget", "lucro", "title_year"]].query("title_year > 2000").corr()
# Out:
#                gross    budget     lucro  title_year
# gross       1.000000  0.708622  0.770074    0.102319
# budget      0.708622  1.000000  0.095558    0.059220
# lucro       0.770074  0.095558  1.000000    0.028288
# title_year  0.102319  0.059220  0.028288    1.000000

# %% [markdown]
# ## Desafio 9 da [Thais André](https://twitter.com/thais_tandre)
#
# Analisar e interpretar a correlação de outras variáveis além das feitas em sala (notas é uma boa). Número de avaliações por ano pode ser também uma feature.

# %%
imdb_usa.head()
# Out:
#    color      director_name  ...  movie_facebook_likes        lucro
# 0  Color      James Cameron  ...                 33000  523505847.0
# 1  Color     Gore Verbinski  ...                     0    9404152.0
# 3  Color  Christopher Nolan  ...                164000  198130642.0
# 5  Color     Andrew Stanton  ...                 24000 -190641321.0
# 6  Color          Sam Raimi  ...                     0   78530303.0
#
# [5 rows x 29 columns]

# %%
imdb_usa.query("title_year > 2000")[["imdb_score", "movie_facebook_likes", "lucro", "num_user_for_reviews"]].corr()
# Out:
#                       imdb_score  ...  num_user_for_reviews
# imdb_score              1.000000  ...              0.330845
# movie_facebook_likes    0.312508  ...              0.410836
# lucro                   0.243152  ...              0.416336
# num_user_for_reviews    0.330845  ...              1.000000
#
# [4 rows x 4 columns]
